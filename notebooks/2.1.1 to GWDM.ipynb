# %%
from node_plotter import ModelMapper
import json

# %%
data_example = json.load(open("example_2_1_1.json"))
extra = {
    'pid':1234,
    'id':1235,
    'pathwayDescription':'to be removed?'
}

# %%
mapper = ModelMapper(data_example,'hdrukv211','gdmv1',extra=extra,render=False)

# %%
dot = mapper.get_diagram()
dot
# Out:
# hdrukv211.coverage.physicalSampleAvailability  -->  gdmv1.coverage.physicalSampleAvailability  ( list --> str )
# hdrukv211.coverage.spatial  -->  gdmv1.coverage.spatial  ( list --> str )
# hdrukv211.provenance.origin.purpose  -->  gdmv1.provenance.origin.purpose  ( list --> str )
# hdrukv211.provenance.origin.source  -->  gdmv1.provenance.origin.source  ( list --> str )
# hdrukv211.accessibility.access.jurisdiction  -->  gdmv1.accessibility.access.jurisdiction  ( list --> str )
# hdrukv211.accessibility.access.accessRights  -->  gdmv1.accessibility.access.accessRights  ( list --> str )
# hdrukv211.accessibility.access.accessRequestCost  -->  gdmv1.accessibility.access.accessRequestCost  ( list --> str )
# hdrukv211.accessibility.usage.dataUseLimitation  -->  gdmv1.accessibility.usage.dataUseLimitation  ( list --> str )
# hdrukv211.accessibility.usage.dataUseRequirements  -->  gdmv1.accessibility.usage.dataUseRequirement  ( list --> str )
# hdrukv211.accessibility.usage.resourceCreator  -->  gdmv1.accessibility.usage.resourceCreator  ( list --> str )
# hdrukv211.accessibility.formatAndStandards.vocabularyEncodingScheme  -->  gdmv1.accessibility.formatAndStandards.vocabularyEncodingSchemes  ( list --> str )
# hdrukv211.accessibility.formatAndStandards.conformsTo  -->  gdmv1.accessibility.formatAndStandards.conformsTo  ( list --> str )
# hdrukv211.accessibility.formatAndStandards.language  -->  gdmv1.accessibility.formatAndStandards.languages  ( list --> str )
# hdrukv211.accessibility.formatAndStandards.format  -->  gdmv1.accessibility.formatAndStandards.formats  ( list --> str )
# hdrukv211.accessibility.usage.isReferencedBy  -->  gdmv1.linkage.isReferenceIn  ( list --> str )
# hdrukv211.enrichmentAndLinkage.tools  -->  gdmv1.linkage.tools  ( list --> str )
# hdrukv211.enrichmentAndLinkage.derivation  -->  gdmv1.linkage.datasetLinkage.isDerivedFrom  ( list --> str )

# %%
mapper.save_diagram()

# %%
with open('example_gdm1.json','w') as f:
    json.dump(mapper.output_metadata,f,indent=6)

# %%
import pandas as pd

# %%
t0 = pd.DataFrame(mapper.connectors).sort_values('from')#.set_index('from')
#tab['from'].str.split(".", expand = True).fillna('')
t0
# Out:
#                                                  from  \
# 30   hdrukv211.accessibility.access.accessRequestCost
# 28        hdrukv211.accessibility.access.accessRights
# 29       hdrukv211.accessibility.access.accessService
# 26      hdrukv211.accessibility.access.dataController
# 27       hdrukv211.accessibility.access.dataProcessor
# 24    hdrukv211.accessibility.access.deliveryLeadTime
# 25        hdrukv211.accessibility.access.jurisdiction
# 35  hdrukv211.accessibility.formatAndStandards.con...
# 37  hdrukv211.accessibility.formatAndStandards.format
# 36  hdrukv211.accessibility.formatAndStandards.lan...
# 34  hdrukv211.accessibility.formatAndStandards.voc...
# 31    hdrukv211.accessibility.usage.dataUseLimitation
# 32  hdrukv211.accessibility.usage.dataUseRequirements
# 39       hdrukv211.accessibility.usage.isReferencedBy
# 33      hdrukv211.accessibility.usage.resourceCreator
# 16                        hdrukv211.coverage.followup
# 13                         hdrukv211.coverage.pathway
# 14      hdrukv211.coverage.physicalSampleAvailability
# 15                         hdrukv211.coverage.spatial
# 17                 hdrukv211.coverage.typicalAgeRange
# 38            hdrukv211.documentation.associatedMedia
# 7                 hdrukv211.documentation.description
# 42                   hdrukv211.documentation.isPartOf
# 41          hdrukv211.enrichmentAndLinkage.derivation
# 40               hdrukv211.enrichmentAndLinkage.tools
# 0                                    hdrukv211.issued
# 1                                  hdrukv211.modified
# 46            hdrukv211.observations.measuredProperty
# 44               hdrukv211.observations.measuredValue
# 45             hdrukv211.observations.observationDate
# 43                hdrukv211.observations.observedNode
# 18                hdrukv211.provenance.origin.purpose
# 19                 hdrukv211.provenance.origin.source
# 23   hdrukv211.provenance.temporal.accrualPeriodicity
# 20              hdrukv211.provenance.temporal.endDate
# 21            hdrukv211.provenance.temporal.startDate
# 22              hdrukv211.provenance.temporal.timeLag
# 3                             hdrukv211.revisions.url
# 2                         hdrukv211.revisions.version
# 10                         hdrukv211.summary.abstract
# 4                          hdrukv211.summary.abstract
# 5                      hdrukv211.summary.contactPoint
# 8                           hdrukv211.summary.doiName
# 6                          hdrukv211.summary.keywords
# 12             hdrukv211.summary.publisher.identifier
# 11                   hdrukv211.summary.publisher.name
# 9                             hdrukv211.summary.title
#
#                                                    to           mod
# 30       gdmv1.accessibility.access.accessRequestCost  list --> str
# 28            gdmv1.accessibility.access.accessRights  list --> str
# 29           gdmv1.accessibility.access.accessService          None
# 26          gdmv1.accessibility.access.dataController          None
# 27           gdmv1.accessibility.access.dataProcessor          None
# 24        gdmv1.accessibility.access.deliveryLeadTime          None
# 25            gdmv1.accessibility.access.jurisdiction  list --> str
# 35  gdmv1.accessibility.formatAndStandards.conformsTo  list --> str
# 37     gdmv1.accessibility.formatAndStandards.formats  list --> str
# 36   gdmv1.accessibility.formatAndStandards.languages  list --> str
# 34  gdmv1.accessibility.formatAndStandards.vocabul...  list --> str
# 31        gdmv1.accessibility.usage.dataUseLimitation  list --> str
# 32       gdmv1.accessibility.usage.dataUseRequirement  list --> str
# 39                        gdmv1.linkage.isReferenceIn  list --> str
# 33          gdmv1.accessibility.usage.resourceCreator  list --> str
# 16                            gdmv1.coverage.followup          None
# 13                             gdmv1.coverage.pathway          None
# 14          gdmv1.coverage.physicalSampleAvailability  list --> str
# 15                             gdmv1.coverage.spatial  list --> str
# 17                     gdmv1.coverage.typicalAgeRange          None
# 38                      gdmv1.linkage.associatedMedia          None
# 7                           gdmv1.summary.description          None
# 42              gdmv1.linkage.datasetLinkage.isPartOf          None
# 41         gdmv1.linkage.datasetLinkage.isDerivedFrom  list --> str
# 40                                gdmv1.linkage.tools  list --> str
# 0                               gdmv1.required.issued          None
# 1                             gdmv1.required.modified          None
# 46                gdmv1.observations.measuredProperty          None
# 44                   gdmv1.observations.measuredValue          None
# 45                 gdmv1.observations.observationDate          None
# 43                    gdmv1.observations.observedNode          None
# 18                    gdmv1.provenance.origin.purpose  list --> str
# 19                     gdmv1.provenance.origin.source  list --> str
# 23       gdmv1.provenance.temporal.accrualPeriodicity          None
# 20                  gdmv1.provenance.temporal.endDate          None
# 21                gdmv1.provenance.temporal.startDate          None
# 22                  gdmv1.provenance.temporal.timeLag          None
# 3                        gdmv1.required.revisions.url          None
# 2                    gdmv1.required.revisions.version          None
# 10                                gdmv1.summary.title          None
# 4                              gdmv1.summary.abstract          None
# 5                          gdmv1.summary.contactPoint          None
# 8                               gdmv1.summary.doiName          None
# 6                              gdmv1.summary.keywords          None
# 12                 gdmv1.publisher.publisherGatewayId          None
# 11                      gdmv1.publisher.publisherName          None
# 9                            gdmv1.summary.shortTitle          None

# %%
t1 = pd.DataFrame(mapper.inodes).rename({'name':'from'},axis=1)
parents = t1['parent'].unique()
t1 = t1[~t1['from'].isin(parents)][['from']]
t1
# Out:
#                                                 from
# 0                               hdrukv211.identifier
# 1                                  hdrukv211.version
# 3                        hdrukv211.revisions.version
# 4                            hdrukv211.revisions.url
# 5                                   hdrukv211.issued
# ..                                               ...
# 73               hdrukv211.observations.observedNode
# 74              hdrukv211.observations.measuredValue
# 75  hdrukv211.observations.disambiguatingDescription
# 76            hdrukv211.observations.observationDate
# 77           hdrukv211.observations.measuredProperty
#
# [64 rows x 1 columns]

# %%
t2 = pd.DataFrame(mapper.onodes).rename({'name':'to'},axis=1)
parents = t2['parent'].unique()
t2 = t2[~t2['to'].isin(parents)][['to']]
t2
# Out:
#                                                    to
# 1                               gdmv1.required.issued
# 2                             gdmv1.required.modified
# 4                    gdmv1.required.revisions.version
# 5                        gdmv1.required.revisions.url
# 7                              gdmv1.summary.abstract
# 8                          gdmv1.summary.contactPoint
# 9                              gdmv1.summary.keywords
# 10                   gdmv1.summary.controlledKeywords
# 11                          gdmv1.summary.description
# 12                              gdmv1.summary.doiName
# 13                           gdmv1.summary.shortTitle
# 14                                gdmv1.summary.title
# 16                      gdmv1.publisher.publisherName
# 17                 gdmv1.publisher.publisherGatewayId
# 19                             gdmv1.coverage.pathway
# 20          gdmv1.coverage.physicalSampleAvailability
# 21                             gdmv1.coverage.spatial
# 22                            gdmv1.coverage.followup
# 23                     gdmv1.coverage.typicalAgeRange
# 26                    gdmv1.provenance.origin.purpose
# 27                     gdmv1.provenance.origin.source
# 29                  gdmv1.provenance.temporal.endDate
# 30                gdmv1.provenance.temporal.startDate
# 31                  gdmv1.provenance.temporal.timeLag
# 32       gdmv1.provenance.temporal.accrualPeriodicity
# 35        gdmv1.accessibility.access.deliveryLeadTime
# 36            gdmv1.accessibility.access.jurisdiction
# 37          gdmv1.accessibility.access.dataController
# 38           gdmv1.accessibility.access.dataProcessor
# 39            gdmv1.accessibility.access.accessRights
# 40           gdmv1.accessibility.access.accessService
# 41       gdmv1.accessibility.access.accessRequestCost
# 43        gdmv1.accessibility.usage.dataUseLimitation
# 44       gdmv1.accessibility.usage.dataUseRequirement
# 45          gdmv1.accessibility.usage.resourceCreator
# 47  gdmv1.accessibility.formatAndStandards.vocabul...
# 48  gdmv1.accessibility.formatAndStandards.conformsTo
# 49   gdmv1.accessibility.formatAndStandards.languages
# 50     gdmv1.accessibility.formatAndStandards.formats
# 52                      gdmv1.linkage.associatedMedia
# 53                        gdmv1.linkage.isReferenceIn
# 54                                gdmv1.linkage.tools
# 56         gdmv1.linkage.datasetLinkage.isDerivedFrom
# 57              gdmv1.linkage.datasetLinkage.isPartOf
# 59                    gdmv1.observations.observedNode
# 60                   gdmv1.observations.measuredValue
# 61                 gdmv1.observations.observationDate
# 62                gdmv1.observations.measuredProperty

# %%
tab = t1.merge(t0,on='from',how='left').merge(t2,on='to',how='outer').fillna('').set_index('from')
tab
# Out:
#                                                                            to  \
# from
# hdrukv211.identifier
# hdrukv211.version
# hdrukv211.summary.publisher.memberOf
# hdrukv211.summary.publisher.contactPoint
# hdrukv211.summary.publisher.logo
# ...                                                                       ...
# hdrukv211.observations.observedNode           gdmv1.observations.observedNode
# hdrukv211.observations.measuredValue         gdmv1.observations.measuredValue
# hdrukv211.observations.observationDate     gdmv1.observations.observationDate
# hdrukv211.observations.measuredProperty   gdmv1.observations.measuredProperty
#                                              gdmv1.summary.controlledKeywords
#
#                                          mod
# from
# hdrukv211.identifier
# hdrukv211.version
# hdrukv211.summary.publisher.memberOf
# hdrukv211.summary.publisher.contactPoint
# hdrukv211.summary.publisher.logo
# ...                                       ..
# hdrukv211.observations.observedNode
# hdrukv211.observations.measuredValue
# hdrukv211.observations.observationDate
# hdrukv211.observations.measuredProperty
#
#
# [66 rows x 2 columns]

# %%
print (tab.to_markdown())
# Out:
# | from                                                                | to                                                               | mod          |
# |:--------------------------------------------------------------------|:-----------------------------------------------------------------|:-------------|
# | hdrukv211.identifier                                                |                                                                  |              |
# | hdrukv211.version                                                   |                                                                  |              |
# | hdrukv211.summary.publisher.memberOf                                |                                                                  |              |
# | hdrukv211.summary.publisher.contactPoint                            |                                                                  |              |
# | hdrukv211.summary.publisher.logo                                    |                                                                  |              |
# | hdrukv211.summary.publisher.description                             |                                                                  |              |
# | hdrukv211.summary.publisher.accessRights                            |                                                                  |              |
# | hdrukv211.summary.publisher.deliveryLeadTime                        |                                                                  |              |
# | hdrukv211.summary.publisher.accessService                           |                                                                  |              |
# | hdrukv211.summary.publisher.accessRequestCost                       |                                                                  |              |
# | hdrukv211.summary.publisher.dataUseLimitation                       |                                                                  |              |
# | hdrukv211.summary.publisher.dataUseRequirements                     |                                                                  |              |
# | hdrukv211.summary.alternateIdentifiers                              |                                                                  |              |
# | hdrukv211.provenance.origin.collectionSituation                     |                                                                  |              |
# | hdrukv211.provenance.temporal.distributionReleaseDate               |                                                                  |              |
# | hdrukv211.accessibility.usage.investigations                        |                                                                  |              |
# | hdrukv211.enrichmentAndLinkage.qualifiedRelation                    |                                                                  |              |
# | hdrukv211.observations.disambiguatingDescription                    |                                                                  |              |
# | hdrukv211.revisions.version                                         | gdmv1.required.revisions.version                                 |              |
# | hdrukv211.revisions.url                                             | gdmv1.required.revisions.url                                     |              |
# | hdrukv211.issued                                                    | gdmv1.required.issued                                            |              |
# | hdrukv211.modified                                                  | gdmv1.required.modified                                          |              |
# | hdrukv211.summary.title                                             | gdmv1.summary.shortTitle                                         |              |
# | hdrukv211.summary.abstract                                          | gdmv1.summary.title                                              |              |
# | hdrukv211.summary.abstract                                          | gdmv1.summary.abstract                                           |              |
# | hdrukv211.summary.publisher.name                                    | gdmv1.publisher.publisherName                                    |              |
# | hdrukv211.summary.publisher.identifier                              | gdmv1.publisher.publisherGatewayId                               |              |
# | hdrukv211.summary.contactPoint                                      | gdmv1.summary.contactPoint                                       |              |
# | hdrukv211.summary.keywords                                          | gdmv1.summary.keywords                                           |              |
# | hdrukv211.summary.doiName                                           | gdmv1.summary.doiName                                            |              |
# | hdrukv211.documentation.description                                 | gdmv1.summary.description                                        |              |
# | hdrukv211.documentation.associatedMedia                             | gdmv1.linkage.associatedMedia                                    |              |
# | hdrukv211.documentation.isPartOf                                    | gdmv1.linkage.datasetLinkage.isPartOf                            |              |
# | hdrukv211.coverage.followup                                         | gdmv1.coverage.followup                                          |              |
# | hdrukv211.coverage.spatial                                          | gdmv1.coverage.spatial                                           | list --> str |
# | hdrukv211.coverage.physicalSampleAvailability                       | gdmv1.coverage.physicalSampleAvailability                        | list --> str |
# | hdrukv211.coverage.pathway                                          | gdmv1.coverage.pathway                                           |              |
# | hdrukv211.coverage.typicalAgeRange                                  | gdmv1.coverage.typicalAgeRange                                   |              |
# | hdrukv211.provenance.origin.purpose                                 | gdmv1.provenance.origin.purpose                                  | list --> str |
# | hdrukv211.provenance.origin.source                                  | gdmv1.provenance.origin.source                                   | list --> str |
# | hdrukv211.provenance.temporal.timeLag                               | gdmv1.provenance.temporal.timeLag                                |              |
# | hdrukv211.provenance.temporal.accrualPeriodicity                    | gdmv1.provenance.temporal.accrualPeriodicity                     |              |
# | hdrukv211.provenance.temporal.startDate                             | gdmv1.provenance.temporal.startDate                              |              |
# | hdrukv211.provenance.temporal.endDate                               | gdmv1.provenance.temporal.endDate                                |              |
# | hdrukv211.accessibility.usage.dataUseLimitation                     | gdmv1.accessibility.usage.dataUseLimitation                      | list --> str |
# | hdrukv211.accessibility.usage.resourceCreator                       | gdmv1.accessibility.usage.resourceCreator                        | list --> str |
# | hdrukv211.accessibility.usage.dataUseRequirements                   | gdmv1.accessibility.usage.dataUseRequirement                     | list --> str |
# | hdrukv211.accessibility.usage.isReferencedBy                        | gdmv1.linkage.isReferenceIn                                      | list --> str |
# | hdrukv211.accessibility.access.dataController                       | gdmv1.accessibility.access.dataController                        |              |
# | hdrukv211.accessibility.access.jurisdiction                         | gdmv1.accessibility.access.jurisdiction                          | list --> str |
# | hdrukv211.accessibility.access.dataProcessor                        | gdmv1.accessibility.access.dataProcessor                         |              |
# | hdrukv211.accessibility.access.accessService                        | gdmv1.accessibility.access.accessService                         |              |
# | hdrukv211.accessibility.access.accessRights                         | gdmv1.accessibility.access.accessRights                          | list --> str |
# | hdrukv211.accessibility.access.accessRequestCost                    | gdmv1.accessibility.access.accessRequestCost                     | list --> str |
# | hdrukv211.accessibility.access.deliveryLeadTime                     | gdmv1.accessibility.access.deliveryLeadTime                      |              |
# | hdrukv211.accessibility.formatAndStandards.language                 | gdmv1.accessibility.formatAndStandards.languages                 | list --> str |
# | hdrukv211.accessibility.formatAndStandards.vocabularyEncodingScheme | gdmv1.accessibility.formatAndStandards.vocabularyEncodingSchemes | list --> str |
# | hdrukv211.accessibility.formatAndStandards.format                   | gdmv1.accessibility.formatAndStandards.formats                   | list --> str |
# | hdrukv211.accessibility.formatAndStandards.conformsTo               | gdmv1.accessibility.formatAndStandards.conformsTo                | list --> str |
# | hdrukv211.enrichmentAndLinkage.tools                                | gdmv1.linkage.tools                                              | list --> str |
# | hdrukv211.enrichmentAndLinkage.derivation                           | gdmv1.linkage.datasetLinkage.isDerivedFrom                       | list --> str |
# | hdrukv211.observations.observedNode                                 | gdmv1.observations.observedNode                                  |              |
# | hdrukv211.observations.measuredValue                                | gdmv1.observations.measuredValue                                 |              |
# | hdrukv211.observations.observationDate                              | gdmv1.observations.observationDate                               |              |
# | hdrukv211.observations.measuredProperty                             | gdmv1.observations.measuredProperty                              |              |
# |                                                                     | gdmv1.summary.controlledKeywords                                 |              |
